# %% [markdown]
# -----------------------------------------------Bài tập chương 2------------------------------------------------

# %% [markdown]
# Bài tập 1:

# %%
chieudai=float(input("Nhập vào chiều dài căn phòng: "))
chieurong=float(input("Nhập vào chiều rộng căn phòng: "))
print(f"Chiều dài căn phòng: {chieudai}")
print(f"Chiều dài căn phòng: {chieurong}")
# Out:
# Nhập vào chiều dài căn phòng:  12.5
# Nhập vào chiều rộng căn phòng:  62.8
# Chiều dài căn phòng: 12.5
# Chiều dài căn phòng: 62.8

# %% [markdown]
# Bài tập 2:

# %%
chieudai=float(input("Nhập vào chiều dài căn phòng: "))
chieurong=float(input("Nhập vào chiều rộng căn phòng: "))
if chieudai>=0 and chieurong>=0:
  dientich=chieudai*chieurong
  mauanh=dientich/43560
  print(f"diện tích theo mẫu anh: {mauanh: 0.2f}")
else:
  print(f"Lỗi nhập số liệu âm, mời bạn nhập lại")
# Out:
# Nhập vào chiều dài căn phòng:  12.5

# %% [markdown]
# Bài tập 3:

# %%
#-------Bài tập 3
chiphi=int(input("Nhập vào chi phí của bữa ăn: "))
if chiphi>=0:
    boa=0.18*chiphi
    thue=0.05*chiphi
    print(f"tiền boa: {boa}")
    print(f"tiền thuế: {thue}")
else:
    print(f"Lỗi nhập số liệu, mời bạn nhập lại")
# Out:
# Nhập vào chi phí của bữa ăn:  230000
# tiền boa: 41400.0
# tiền thuế: 11500.0

# %% [markdown]
# Bài tập 4:

# %%
n=int(input("Nhập vào số nguyên n: "))
for i in range(1,n+1):
    sum=((n)*(n+1))/2
print (f"Tổng của n số nguyên dương là: {sum}")
# Out:
# Nhập vào số nguyên n:  5
# Tổng của n số nguyên dương là: 15.0

# %% [markdown]
# Bài tập 5

# %%
from math import *
a=int(input("Nhập vào số nguyên a"))
b=int(input("Nhập vào số nguyên b"))
print(f"Tổng của a và b: {a+b}")
print(f"Hiệu của a và b: {a-b}")
print(f"Tích của a và b: {a*b}")
print(f"Thương của a và b: {a/b}")
print(f"Số dư của a và b: {a%b}")
print(f"log của a và b: {log(10,a)}")
print(f"a^b: {a**b}")
# Out:
# Nhập vào số nguyên a 21
# Nhập vào số nguyên b 15
# Tổng của a và b: 36
# Hiệu của a và b: 6
# Tích của a và b: 315
# Thương của a và b: 1.4
# Số dư của a và b: 6
# log của a và b: 0.7563041955164012
# a^b: 68122318582951682301

# %% [markdown]
# Bài tập 6:

# %%
from math import *
m=float(input("Nhập vào khối lượng nước: "))
deltaT=float(input("Nhập vào lượng thay đổi nhiệt độ: "))
q=m*4.186*deltaT
qkwh=q*2.777*exp(-7)
chiphi=qkwh*8.9
print(f"Nhiệt lượng của nước: {q}")
print(f"Chi phí: {chiphi}")
# Out:
# Nhập vào khối lượng nước:  12
# Nhập vào lượng thay đổi nhiệt độ:  3
# Nhiệt lượng của nước: 150.696
# Chi phí: 3.396301507185346

# %% [markdown]
# Bài tập 7:

# %%
from math import *
def check(d):
    if d>=0:
        tocdo(d)
    else:
        print("Lỗi! Vui lòng kiểm tra lại chiều cao")
def speed(d):
    a=9.8
    v1=0
    print(f"Tốc độ cuối cùng của vật là: {sqrt(v1**2+2*a*d)}")
d=float(input("Nhập vào chiều cao của vật được thả: "))
check(d)
# Out:
# Nhập vào chiều cao của vật được thả:  12
# Tốc độ cuối cùng của vật là: 15.336231610144651

# %% [markdown]
# Bài tập 8:

# %%
from math import *
def check(s,n):
    if s>=0:
        if n>=0:
            dientich(s,n)
        else:
            print("Lỗi! Vui lòng kiểm tra lại")
    else:
        print("Lỗi! Vui lòng kiểm tra lại")

def area(s,n):
    print(f"Diện tích đa giác: {(n*s**2)/(4*tan(pi/n))}")
s=float(input("Chiều dài của cạnh đa giác: "))
n=float(input("Số cạnh của đa giác: "))
check(s,n)
# Out:
# Chiều dài của cạnh đa giác:  12.3
# Số cạnh của đa giác:  -5.6
# Lỗi! Vui lòng kiểm tra lại

# %% [markdown]
# Bài tập 9:

# %%
def calculate(sec):
    d=sec/86400;
    sec=sec%86400;
    h=sec/3600;
    sec=sec%3600;
    m=sec/60;
    sec=sec%60;
    print(f"{int(d)}:{int(h)}:{int(m)}:{int(sec)}")
def check(sec):
    if sec>=0:
        if sec>=0:
            calculate(sec)
        else:
            print("Lỗi! Vui lòng kiểm tra lại")
    else:
        print("Lỗi! Vui lòng kiểm tra lại")

sec=int(input("Nhập vào số giây trong giờ phút giây: "))
check(sec)
# Out:
# Nhập vào số giây trong giờ phút giây:  -3600
# Lỗi! Vui lòng kiểm tra lại

# %% [markdown]
# Bài tập 10:

# %%
from math import *
#print(f"Chỉ số gió lạnh: {round(13.12 + 0.6215*ta - 11.37*v**0.16 + 0,3965*ta*v**0.16,2)}")
def check(ta):
        if ta>=0:
            calculate(ta,v)
        else:
            print("Lỗi! Vui lòng kiểm tra lại")
def calculate(ta,v):
    wci=13.12 + 0.6215*ta - 11.37*v**0.16 + 0.3965*ta*v**0.16
    print(f"Chỉ số gió lạnh: {round(wci,2)}")

ta=float(input("Nhập vào nhiệt độ không khí: "))
v=float(input("Tốc độ gió: "))
check(ta)
# Out:
# Nhập vào nhiệt độ không khí:  13.6
# Tốc độ gió:  3.5
# Chỉ số gió lạnh: 14.27

# %% [markdown]
# Bài tập 11:

# %%
from math import *
a1=int(input("Nhập vào số nguyên thứ nhất: "))
a2=int(input("Nhập vào số nguyên thứ hai: "))
a3=int(input("Nhập vào số nguyên thứ ba: "))
print(f"{min(a1,a2,a3)}, {(a1+a2+a3)-min(a1,a2,a3)-max(a1,a2,a3)}, {max(a1,a2,a3)}")
# Out:
# Nhập vào số nguyên thứ nhất: 11
# Nhập vào số nguyên thứ hai: 32
# Nhập vào số nguyên thứ ba: 2
# 2, 11, 32

# %% [markdown]
# Bài tập 12:

# %%
quantity=int(input("Nhập vào số lượng bánh mì bạn muốn: "))
print(f"giá tiền gốc: 3.49")
print(f"giá giảm 30%: {round(0.6*3.49,2)}")
print(f"tổng giá phải trả: {round(quantity*3.49-0.6*3.49,2)}")
# Out:
# Nhập vào số lượng bánh mì bạn muốn: 2
# giá tiền gốc: 3.49
# giá giảm 30%: 2.09
# tổng giá phải trả: 4.89
